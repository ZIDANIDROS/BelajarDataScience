# %% [markdown]
# <a href="https://colab.research.google.com/github/ZIDANIDROS/BelajarDataScience/blob/main/4522210012_husein_zidan_SPK_uts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UJIAN TENGAH SEMESTER <br>
# Nama : Husein Zidan <br>
# NPM  : 4522210012 <br>
# Mata Kuliah : Sistem Pendukung Keputusan <br>
# Dosen Pengampu : Ninuk Wiliani , S.Si., M.Kom., Phd.

# %%
import pandas as pd
import numpy as np

data = {
    "Nama Produk": [
        "Gamis Hijab", "Jilbab Syar'ih", "Cadar", "Gamis Pesta",
        "Jilbab Modern", "Cadar Premium", "Gamis Kasual",
        "Cadar Sederhana", "Jilbab Lengan Panjang", "Gamis Anak"
    ],
    "Jumlah Penjualan": [50, 30, 20, 40, 10, 25, 35, 15, 45, 28], # Benefit
    "Persentase Penurunan Stok (%)": [15, 7, 2, 20, 13, 10, 5, 8, 18, 3], # Cost
    "Waktu Stok (hari)": [10, 30, 20, 5, 15, 12, 18, 25, 7, 14], # Cost
    "Margin Keuntungan (%)": [20, 25, 15, 18, 30, 22, 15, 12, 28, 19], # Benefit
    "Ketersediaan Restock": [8, 5, 10, 7, 6, 9, 8, 4, 7, 6] # Benefit
}


df = pd.DataFrame(data)
df
# Out:
#              Nama Produk  Jumlah Penjualan  Persentase Penurunan Stok (%)  \
# 0            Gamis Hijab                50                             15
# 1         Jilbab Syar'ih                30                              7
# 2                  Cadar                20                              2
# 3            Gamis Pesta                40                             20
# 4          Jilbab Modern                10                             13
# 5          Cadar Premium                25                             10
# 6           Gamis Kasual                35                              5
# 7        Cadar Sederhana                15                              8
# 8  Jilbab Lengan Panjang                45                             18
# 9             Gamis Anak                28                              3
#
#    Waktu Stok (hari)  Margin Keuntungan (%)  Ketersediaan Restock
# 0                 10                     20                     8
# ...

# %%
# Mengubah nama produk menjadi A1-A10
df.index = [f"A{i+1}" for i in range(len(df))]

# Mengubah nama kolom menjadi C1-C5
df.columns = ["Nama Produk", "C1", "C2", "C3", "C4", "C5"]

# Menampilkan hasil
df
# Out:
#                Nama Produk  C1  C2  C3  C4  C5
# A1             Gamis Hijab  50  15  10  20   8
# A2          Jilbab Syar'ih  30   7  30  25   5
# A3                   Cadar  20   2  20  15  10
# A4             Gamis Pesta  40  20   5  18   7
# A5           Jilbab Modern  10  13  15  30   6
# A6           Cadar Premium  25  10  12  22   9
# A7            Gamis Kasual  35   5  18  15   8
# A8         Cadar Sederhana  15   8  25  12   4
# A9   Jilbab Lengan Panjang  45  18   7  28   7
# A10             Gamis Anak  28   3  14  19   6

# %%
# Bobot untuk Jumlah Penjualan, Persentase Penurunan Stok, Waktu Stok, Margin Keuntungan
weights = np.array([0.3, 0.25, 0.2, 0.15, 0.1])

df_weights = pd.DataFrame({
    'Kriteria': ['C1', 'C2', 'C3', 'C4', 'C5'],
    'Bobot': weights
})

print("Bobot Kriteria:")
df_weights
# Out:
# Bobot Kriteria:
#   Kriteria  Bobot
# 0       C1   0.30
# 1       C2   0.25
# 2       C3   0.20
# 3       C4   0.15
# 4       C5   0.10

# %%
# Matriks normalisasi R'
R = df[["C1", "C2", "C3", "C4", "C5"]] / np.sqrt((df[["C1", "C2", "C3", "C4", "C5"]] ** 2).sum())
print("Matriks normalisasi R' :")
R
# Out:
#            C1        C2        C3        C4        C5
# A1   0.490668  0.405405  0.182940  0.299074  0.350823
# A2   0.294401  0.189189  0.548821  0.373843  0.219265
# A3   0.196267  0.054054  0.365881  0.224306  0.438529
# A4   0.392534  0.540541  0.091470  0.269167  0.306970
# A5   0.098134  0.351351  0.274411  0.448611  0.263117
# A6   0.245334  0.270270  0.219529  0.328982  0.394676
# A7   0.343468  0.135135  0.329293  0.224306  0.350823
# A8   0.147200  0.216216  0.457351  0.179445  0.175412
# A9   0.441601  0.486486  0.128058  0.418704  0.306970
# A10  0.274774  0.081081  0.256117  0.284121  0.263117

# %%
# Mengalikan matriks normalisasi dengan bobot Y
Y = R * weights

# Menampilkan hasil
print("Matriks Normalisasi Terbobot (C1-C5):")
Y
# Out:
# Matriks Normalisasi Terbobot (C1-C5):
#            C1        C2        C3        C4        C5
# A1   0.147200  0.101351  0.036588  0.044861  0.035082
# A2   0.088320  0.047297  0.109764  0.056076  0.021926
# A3   0.058880  0.013514  0.073176  0.033646  0.043853
# A4   0.117760  0.135135  0.018294  0.040375  0.030697
# A5   0.029440  0.087838  0.054882  0.067292  0.026312
# A6   0.073600  0.067568  0.043906  0.049347  0.039468
# A7   0.103040  0.033784  0.065859  0.033646  0.035082
# A8   0.044160  0.054054  0.091470  0.026917  0.017541
# A9   0.132480  0.121622  0.025612  0.062806  0.030697
# A10  0.082432  0.020270  0.051223  0.042618  0.026312

# %%
# Menghitung nilai ideal positif (A+)
A_plus = [
    Y.max()[0],  # max for C1 (Benefit)
    Y.min()[1],  # min for C2 (Cost)
    Y.min()[2],  # min for C3 (Cost)
    Y.max()[3],  # max for C4 (Benefit)
    Y.max()[4]   # max for C5 (Benefit)
]

# Menghitung nilai ideal negatif (A-)
A_minus = [
    Y.min()[0],  # min for C1 (Benefit)
    Y.max()[1],  # max for C2 (Cost)
    Y.max()[2],  # max for C3 (Cost)
    Y.min()[3],  # min for C4 (Benefit)
    Y.min()[4]   # min for C5 (Benefit)
]
# Out:
# <ipython-input-8-5f6e86a74b04>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Y.max()[0],  # max for C1 (Benefit)
# <ipython-input-8-5f6e86a74b04>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Y.min()[1],  # min for C2 (Cost)
# <ipython-input-8-5f6e86a74b04>:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Y.min()[2],  # min for C3 (Cost)
# ...

# %%
print("Ideal Positif (A+):")
A_plus
# Out:
# Ideal Positif (A+):
# [0.14720037599603616,
#  0.013513513513513514,
#  0.018294043331615058,
#  0.06729171801239016,
#  0.043852900965351466]

# %%
print("Ideal Negatif (A-):")
A_minus
# Out:
# Ideal Negatif (A-):
# [0.029440075199207237,
#  0.13513513513513514,
#  0.10976425998969036,
#  0.026916687204956064,
#  0.01754116038614059]

# %%
# Menghitung D+ dan D-
D_plus = np.sqrt(((Y - A_plus) ** 2).sum(axis=1))
D_minus = np.sqrt(((Y - A_minus) ** 2).sum(axis=1))

# Menampilkan hasil
print("D+:\n", D_plus)
print("===================")
print("D-:\n", D_minus)
# Out:
# D+:
#  A1     0.092899
# A2     0.116540
# A3     0.109291
# A4     0.128671
# A5     0.145045
# A6     0.096623
# A7     0.076370
# A8     0.141202
# A9     0.110231
# A10    0.079002
# dtype: float64
# ...
# D-:
#  A1     0.144891
# A2     0.109781
# A3     0.133172
# A4     0.128536
# A5     0.083404
# A6     0.108797
# A7     0.134051
# A8     0.084413
# A9     0.139078
# A10    0.140544
# dtype: float64

# %%
# Menghitung nilai preferensi (P)
P = D_minus / (D_plus + D_minus)

# Menambahkan nilai preferensi ke DataFrame
df['Preferensi'] = P

# Menampilkan hasil
df
# Out:
#                Nama Produk  C1  C2  C3  C4  C5  Preferensi
# A1             Gamis Hijab  50  15  10  20   8    0.609323
# A2          Jilbab Syar'ih  30   7  30  25   5    0.485068
# A3                   Cadar  20   2  20  15  10    0.549247
# A4             Gamis Pesta  40  20   5  18   7    0.499738
# A5           Jilbab Modern  10  13  15  30   6    0.365087
# A6           Cadar Premium  25  10  12  22   9    0.529631
# A7            Gamis Kasual  35   5  18  15   8    0.637062
# A8         Cadar Sederhana  15   8  25  12   4    0.374145
# A9   Jilbab Lengan Panjang  45  18   7  28   7    0.557855
# A10             Gamis Anak  28   3  14  19   6    0.640156

# %%
# Membuat ranking
df['Rank'] = df['Preferensi'].rank(ascending=False)
df_sorted = df.sort_values(by='Rank', ascending=True)

# Menampilkan hasil
df_sorted[['Nama Produk', 'Preferensi', 'Rank']]
# Out:
#                Nama Produk  Preferensi  Rank
# A10             Gamis Anak    0.640156   1.0
# A7            Gamis Kasual    0.637062   2.0
# A1             Gamis Hijab    0.609323   3.0
# A9   Jilbab Lengan Panjang    0.557855   4.0
# A3                   Cadar    0.549247   5.0
# A6           Cadar Premium    0.529631   6.0
# A4             Gamis Pesta    0.499738   7.0
# A2          Jilbab Syar'ih    0.485068   8.0
# A8         Cadar Sederhana    0.374145   9.0
# A5           Jilbab Modern    0.365087  10.0
